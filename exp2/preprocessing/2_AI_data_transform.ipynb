# %% [markdown]
# # Transfrom AI data (pre-step)
#
# For the AI worker, we use the following three files from the paper [(Alizadeh et al. 2024)](https://doi.org/10.1007/s42001-024-00345-9):
#
#  - `... /google_flan-t5-xl__w_generate/google_flan-t5-xl_ds_1_task_5_sample_100_epochs_3_prompt_max_len_4096_batch_size_4_grad_acc_2.csv`
#  - `... /GPT-3.5/dataset_1_task_5/ds_1_t_5_trn_100--.csv`
#  - `... /Llama-2-70b-chat-hf/all_predictions/ds_1_task_5_sample_250_epochs_3_prompt_max_len_4096_batch_size_4_grad_acc_2_temp_0_05.csv`
#
# This file is available at: https://osf.io/ctgqx/
#
# Note: The tasks and datasets we use are referred to in the paper by the following names:
# ```
# Dataset 1: Content Moderation Tweets (2020-2021)
# - Task 5: Topic Detection
# ```

# %%
import subprocess

# %%
# !pwd
# Out:
# /app/exp2/preprocessing

# %%
subprocess.Popen(['python', 'ai_data_transform_flan.py'], cwd='src_ai_workers/flan-t5') ;

# %%
subprocess.Popen(['python', 'ai_data_transform_gpt35.py'], cwd='src_ai_workers/gpt-3.5') ;

# %%
subprocess.Popen(['python', 'ai_data_transform_llama2-70b.py'], cwd='src_ai_workers/Llama-2-70b-chat-hf') ;
# Out:
# Processing file: google_flan-t5-xl_ds_1_task_5_sample_100_epochs_3_prompt_max_len_4096_batch_size_4_grad_acc_2.csv
# Processing file: ds_1_task_5_sample_250_epochs_3_prompt_max_len_4096_batch_size_4_grad_acc_2_temp_0_05.csv
# Processing file: ds_1_t_5_trn_100--.csv
